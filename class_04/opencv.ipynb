# %% [markdown]
# # OpenCV

# %%
import cv2
import matplotlib.pyplot as plt

# %%
im = cv2.imread('test.jpg') # Read BGR
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
plt.figure()
plt.imshow(im)
np.sa

# %%
print(type(im))

print(im.shape)
print(im.ndim)
# Out:
# <class 'numpy.ndarray'>
# (1200, 1600, 3)
# 3

# %%
gray = cv2.cvtColor(im, cv2.COLOR_RGB2GRAY)

plt.figure()
plt.imshow(gray, cmap='gray')

# %%
print(gray.shape)
# Out:
# (1200, 1600)

# %%
resized_image = cv2.resize(gray, (2000,2000))
plt.figure()
plt.imshow(resized_image, cmap='gray')

# %%
import numpy as np
np.save?

# %%
a = np.array([1,2,3,4,5,6])
a.reshape((2,3))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.reshape((-1,2)).shape
# Out:
# (3, 2)

# %%
cv2.putText?
